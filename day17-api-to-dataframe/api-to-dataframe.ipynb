# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                  Spirited Away
# 6      155                                The Dark Knight
# 7    19404                    Dilwale Dulhania Le Jayenge
# 8      497                                 The Green Mile
# 9   496243                                       Parasite
# 10     122  The Lord of the Rings: The Return of the King
# 11     680                                   Pulp Fiction
# 12  372058                                     Your Name.
# 13     429                 The Good, the Bad and the Ugly
# 14  157336                                   Interstellar
# 15      13                                   Forrest Gump
# 16     769                                     GoodFellas
# 17     346                                  Seven Samurai
# 18   12477                         Grave of the Fireflies
# 19     637                              Life Is Beautiful
#
#                                              overview release_date  \
# 0   Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2   In the continuing saga of the Corleone crime f...   1974-12-20
# 3   The true story of how businessman Oskar Schind...   1993-12-15
# 4   The defense and the prosecution have rested an...   1957-04-10
# 5   A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# 6   Batman raises the stakes in his war on crime. ...   2008-07-16
# 7   Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 8   A supernatural tale set on death row in a Sout...   1999-12-10
# 9   All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 10  As armies mass for a final battle that will de...   2003-12-17
# 11  A burger-loving hit man, his philosophical par...   1994-09-10
# 12  High schoolers Mitsuha and Taki are complete s...   2016-08-26
# 13  While the Civil War rages on between the Union...   1966-12-22
# 14  The adventures of a group of explorers who mak...   2014-11-05
# 15  A man with a low IQ has accomplished great thi...   1994-06-23
# 16  The true story of Henry Hill, a half-Irish, ha...   1990-09-12
# 17  A samurai answers a village's request for prot...   1954-04-26
# 18  In the final months of World War II, 14-year-o...   1988-04-16
# 19  A touching story of an Italian book seller of ...   1997-12-20
#
#     popularity  vote_average  vote_count
# 0      28.6873         8.714       29551
# 1      35.2981         8.687       22313
# 2      18.5173         8.571       13494
# 3      15.6081         8.565       17007
# 4      11.0011         8.552        9663
# 5      18.5507         8.533       17846
# 6      25.4925         8.525       35014
# 7       5.6434         8.518        4541
# 8      18.4050         8.503       18733
# 9      28.5639         8.496       19978
# 10     23.6105         8.493       25879
# 11     22.1757         8.486       29554
# 12     19.0824         8.479       12228
# 13     13.9872         8.468        9354
# 14     46.6906         8.466       38646
# 15     19.5528         8.462       29110
# 16     15.6971         8.452       13923
# 17      7.5758         8.450        4084
# 18      0.0084         8.400        6286
# 19     10.0588         8.440       13731

# %%
# Create an empty list to store DataFrames
dfs = []

for i in range(1, 10):
    response = requests.get(
        f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}'
    )
    temp_df = pd.DataFrame(response.json()['results'])[
        ['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']
    ]
    dfs.append(temp_df)  # store each temp_df in the list

# Concatenate all DataFrames at once
df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#          id                       title  \
# 0       278    The Shawshank Redemption
# 1       238               The Godfather
# 2       240       The Godfather Part II
# 3       424            Schindler's List
# 4       389                12 Angry Men
# ..      ...                         ...
# 175     422                          8½
# 176  406997                      Wonder
# 177    1398                     Stalker
# 178   10681                      WALL·E
# 179  531428  Portrait of a Lady on Fire
#
#                                               overview release_date  \
# 0    Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1    Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2    In the continuing saga of the Corleone crime f...   1974-12-20
# 3    The true story of how businessman Oskar Schind...   1993-12-15
# 4    The defense and the prosecution have rested an...   1957-04-10
# ..                                                 ...          ...
# 175  Guido Anselmi, a film director, finds himself ...   1963-02-14
# 176  The story of August Pullman – a boy with facia...   2017-11-13
# 177  Near a gray and unnamed city is the Zone, a pl...   1979-05-25
# 178  What if mankind had to leave Earth and somebod...   2008-06-22
# 179  On an isolated island in Brittany at the end o...   2019-09-06
#
#      popularity  vote_average  vote_count
# 0       28.6873         8.714       29551
# 1       35.2981         8.687       22313
# 2       18.5173         8.571       13494
# 3       15.6081         8.565       17007
# 4       11.0011         8.552        9663
# ..          ...           ...         ...
# 175      3.8537         8.113        2468
# 176      6.0956         8.111        8136
# 177      3.2186         8.110        2415
# 178     15.7375         8.100       19823
# 179      4.6655         8.100        2836
#
# [180 rows x 7 columns]

# %%
df.to_csv('movies.csv')
